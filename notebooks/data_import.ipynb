# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import datetime
import psycopg2 as pg
import pandas.io.sql as pd_sql

# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline
sns.set(color_codes=True)
plt.style.use('seaborn-colorblind')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)
pd.set_option('display.precision', 5)

# %%
connection_args = {
    'host': 'localhost',  
    'dbname': 'flights',    
    'port': 5432          
}

connection = pg.connect(**connection_args)

# %%
query = """
    SELECT
        f.*,
        a.airline AS airline_name,
        o.airport AS origin_airport_name,
        o.city AS origin_airport_city,
        o.state AS origin_airport_state,
        o.latitude AS origin_airport_latitude,
        o.longitude AS origin_airport_longitude,
        d.airport AS destination_airport_name,
        d.city AS destination_airport_city,
        d.state AS destination_airport_state,
        d.latitude AS destination_airport_latitude,
        d.longitude AS destination_airport_longitude
    FROM flights AS f
        LEFT JOIN airlines AS a
            ON f.airline = a.iata_code
        LEFT JOIN airports AS o
            ON f.origin_airport = o.iata_code
        LEFT JOIN airports AS d
            ON f.destination_airport = d.iata_code
        ORDER BY RANDOM()
        LIMIT 100000;
"""

# %%
query = 'SELECT * FROM sample LIMIT 5'

# %%
pd_sql.read_sql(query, connection)
# Out:
#    year  month  day  day_of_week airline  flight_number tail_number  \
# 0  2015      7   28            2      OO           4640      N806SK
# 1  2015      9   11            5      B6            159      N187JB
# 2  2015      5   29            5      DL           1853      N967AT
# 3  2015      8    6            4      WN           1549      N421LV
# 4  2015      5   12            2      EV           4338      N16178
#
#   origin_airport destination_airport scheduled_departure departure_time  \
# 0            SLC                 DFW                0830           0824
# 1            BOS                 PHL                0630           0630
# 2            MSN                 ATL                0600           0552
# 3            SNA                 OAK                1730           1729
# 4            EWR                 CMH                1210           1206
#
#   departure_delay taxi_out wheels_off scheduled_time elapsed_time air_time  \
# 0              -6       15       0839            156          146      125
# 1               0       11       0641             88           71       56
# 2              -8       18       0610            125          134      103
# 3              -1       13       1742             80           77       59
# 4              -4       16       1222            114           99       76
#
#   distance wheels_on taxi_in scheduled_arrival arrival_time arrival_delay  \
# 0      989      1144       6              1206         1150           -16
# 1      280      0737       4              0758         0741           -17
# 2      707      0853      13              0905         0906             1
# 3      371      1841       5              1850         1846            -4
# 4      463      1338       7              1404         1345           -19
#
#    diverted  cancelled cancellation_reason air_system_delay security_delay  \
# 0         0          0                None             None           None
# 1         0          0                None             None           None
# 2         0          0                None             None           None
# 3         0          0                None             None           None
# 4         0          0                None             None           None
#
#   airline_delay late_aircraft weather_delay                 airline_name  \
# 0          None          None          None        Skywest Airlines Inc.
# 1          None          None          None              JetBlue Airways
# 2          None          None          None         Delta Air Lines Inc.
# 3          None          None          None       Southwest Airlines Co.
# 4          None          None          None  Atlantic Southeast Airlines
#
#                                 origin_airport_name origin_airport_city  \
# 0              Salt Lake City International Airport      Salt Lake City
# 1  Gen. Edward Lawrence Logan International Airport              Boston
# 2                      Dane County Regional Airport             Madison
# 3        John Wayne Airport (Orange County Airport)           Santa Ana
# 4              Newark Liberty International Airport              Newark
#
#   origin_airport_state  origin_airport_latitude  origin_airport_longitude  \
# 0                   UT                 40.78839                -111.97777
# 1                   MA                 42.36435                 -71.00518
# 2                   WI                 43.13986                 -89.33751
# 3                   CA                 33.67566                -117.86822
# 4                   NJ                 40.69250                 -74.16866
#
#                            destination_airport_name destination_airport_city  \
# 0           Dallas/Fort Worth International Airport        Dallas-Fort Worth
# 1                Philadelphia International Airport             Philadelphia
# 2  Hartsfield-Jackson Atlanta International Airport                  Atlanta
# 3                     Oakland International Airport                  Oakland
# 4               Port Columbus International Airport                 Columbus
#
#   destination_airport_state  destination_airport_latitude  \
# 0                        TX                      32.89595
# 1                        PA                      39.87195
# 2                        GA                      33.64044
# 3                        CA                      37.72129
# 4                        OH                      39.99799
#
#    destination_airport_longitude
# 0                      -97.03720
# 1                      -75.24114
# 2                      -84.42694
# 3                     -122.22072
# 4                      -82.89188

# %%
sample_df.month.value_counts()
# Out:
# 7     9011
# 8     8800
# 6     8764
# 5     8602
# 3     8477
# 12    8361
# 10    8329
# 4     8279
# 1     8039
# 9     7989
# 11    7959
# 2     7390
# Name: month, dtype: int64

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 42 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   year                           100000 non-null  int64
#  1   month                          100000 non-null  int64
#  2   day                            100000 non-null  int64
#  3   day_of_week                    100000 non-null  int64
#  4   airline                        100000 non-null  object
#  5   flight_number                  100000 non-null  int64
#  6   tail_number                    99757 non-null   object
#  7   origin_airport                 100000 non-null  object
#  8   destination_airport            100000 non-null  object
#  9   scheduled_departure            100000 non-null  object
#  10  departure_time                 98518 non-null   object
#  11  departure_delay                98518 non-null   object
#  12  taxi_out                       98468 non-null   object
#  13  wheels_off                     98468 non-null   object
#  14  scheduled_time                 100000 non-null  object
#  15  elapsed_time                   98166 non-null   object
#  16  air_time                       98166 non-null   object
#  17  distance                       100000 non-null  object
#  18  wheels_on                      98403 non-null   object
#  19  taxi_in                        98403 non-null   object
#  20  scheduled_arrival              100000 non-null  object
#  21  arrival_time                   98403 non-null   object
#  22  arrival_delay                  98166 non-null   object
#  23  diverted                       100000 non-null  int64
#  24  cancelled                      100000 non-null  int64
#  25  cancellation_reason            1549 non-null    object
#  26  air_system_delay               18293 non-null   object
#  27  security_delay                 18293 non-null   object
#  28  airline_delay                  18293 non-null   object
#  29  late_aircraft                  18293 non-null   object
#  30  weather_delay                  18293 non-null   object
#  31  airline_name                   100000 non-null  object
#  32  origin_airport_name            91671 non-null   object
#  33  origin_airport_city            91671 non-null   object
#  34  origin_airport_state           91671 non-null   object
#  35  origin_airport_latitude        91592 non-null   float64
#  36  origin_airport_longitude       91592 non-null   float64
#  37  destination_airport_name       91671 non-null   object
#  38  destination_airport_city       91671 non-null   object
#  39  destination_airport_state      91671 non-null   object
#  40  destination_airport_latitude   91591 non-null   float64
#  41  destination_airport_longitude  91591 non-null   float64
# dtypes: float64(4), int64(7), object(31)
# memory usage: 32.0+ MB

# %%
with open('sample_df.pickle', 'wb') as to_write:
    pickle.dump(sample_df, to_write)

# %%
query = """
    SELECT 
        origin_airport_name, 
        origin_airport_latitude, 
        origin_airport_longitude, 
        AVG(CAST(arrival_delay AS INTEGER)) AS origin_airport_avg_arrival_delay
    FROM combined
    GROUP BY origin_airport_name, origin_airport_latitude, origin_airport_longitude
    ORDER BY origin_airport_avg_arrival_delay DESC;
"""

# %%
origin_airport_avg_arrival_delay_df = pd_sql.read_sql(query, connection)

# %%
origin_airport_avg_arrival_delay_df = origin_airport_avg_arrival_delay_df.sort_values('origin_airport_avg_arrival_delay', ascending=False)

# %%
# Segment to look at top 100 worst origin_airports in terms of delays
top_delays_df = origin_airport_avg_arrival_delay_df.iloc[0:50]

# %%
top_delays_df.to_csv('top_airport_delays.csv', index=False)

# %%
top_delays_df
# Out:
#                                   origin_airport_name  \
# 0                                  Wilmington Airport
# 1                                    Gustavus Airport
# 2    Pago Pago International Airport (Tafuna Airport)
# 3                          St. Cloud Regional Airport
# 4   Jack Brooks Regional Airport (Southeast Texas ...
# 5                         Aspen-Pitkin County Airport
# 6   Southwest Oregon Regional Airport (North Bend ...
# 7                           Martha's Vineyard Airport
# 8                       Eagle County Regional Airport
# 9                              Trenton Mercer Airport
# 10                          Columbia Regional Airport
# 11                Northwest Arkansas Regional Airport
# 12                   Baton Rouge Metropolitan Airport
# 13                                       Adak Airport
# 14                                     Yeager Airport
# 15                       Duluth International Airport
# 16                        Shreveport Regional Airport
# 17                          Aberdeen Regional Airport
# 18     Del Norte County Airport (Jack McNamara Field)
# 19                         Westchester County Airport
# 20               Springfield-Branson National Airport
# 21                            Joplin Regional Airport
# 22                  Plattsburgh International Airport
# 23                         Nantucket Memorial Airport
# 24                            Albert J. Ellis Airport
# 25                  Charlottesville-Albemarle Airport
# 26                            Dothan Regional Airport
# 27                       Sioux Falls Regional Airport
# 28                        East Texas Regional Airport
# 29  Northeast Florida Regional Airport (St. August...
# 30                   Alexandria International Airport
# 31    Newport News/Williamsburg International Airport
# 32  South Bend International Airport (South Bend R...
# 33              Fresno Yosemite International Airport
# 34                         Erie International Airport
# 35                Atlantic City International Airport
# 36                Hattiesburg-Laurel Regional Airport
# 37                           The Eastern Iowa Airport
# 38              Chippewa County International Airport
# 39            Gunnison-Crested Butte Regional Airport
# 40                       Barnstable Municipal Airport
# 41               Chicago O'Hare International Airport
# 42       Yampa Valley Airport (Yampa Valley Regional)
# 43              Augusta Regional Airport (Bush Field)
# 44                         Santa Fe Municipal Airport
# 45                       Yellowstone Regional Airport
# 46                               McGhee Tyson Airport
# 47                       Gainesville Regional Airport
# 48                    Abraham Lincoln Capital Airport
# 49                                  Dallas Love Field
#
#     origin_airport_latitude  origin_airport_longitude  \
# 0                  39.67872                 -75.60653
# 1                  58.42438                -135.70738
# 2                  14.33102                -170.71053
# 3                  45.54532                 -94.05834
# 4                  29.95083                 -94.02069
# 5                  39.22316                -106.86885
# 6                  43.41714                -124.24603
# 7                  41.39303                 -70.61433
# 8                  39.64257                -106.91770
# 9                  40.27669                 -74.81347
# 10                 38.81809                 -92.21963
# 11                 36.28187                 -94.30681
# 12                 30.53316                 -91.14963
# 13                 51.87796                -176.64603
# 14                 38.37315                 -81.59319
# 15                 46.84209                 -92.19365
# 16                 32.44663                 -93.82560
# 17                 45.44906                 -98.42183
# 18                 41.78016                -124.23653
# 19                 41.06696                 -73.70757
# 20                 37.24433                 -93.38686
# 21                 37.15181                 -94.49827
# 22                      NaN                       NaN
# 23                 41.25305                 -70.06018
# 24                 34.82916                 -77.61214
# 25                 38.13864                 -78.45286
# 26                 31.32134                 -85.44963
# 27                 43.58135                 -96.74170
# 28                 32.38486                 -94.71171
# 29                      NaN                       NaN
# 30                 31.32737                 -92.54856
# 31                 37.13190                 -76.49299
# 32                 41.70895                 -86.31847
# 33                 36.77619                -119.71814
# 34                 42.08202                 -80.17622
# 35                 39.45758                 -74.57717
# 36                 31.46715                 -89.33706
# 37                 41.88459                 -91.71087
# 38                 46.25075                 -84.47239
# 39                 38.53396                -106.93318
# 40                 41.66934                 -70.28036
# 41                 41.97960                 -87.90446
# 42                 40.48118                -107.21766
# 43                 33.36996                 -81.96450
# 44                 35.61678                -106.08814
# 45                 44.52019                -109.02380
# 46                 35.81249                 -83.99286
# 47                 29.69006                 -82.27178
# 48                 39.84395                 -89.67762
# 49                 32.84711                 -96.85177
#
#     origin_airport_avg_arrival_delay
# 0                           24.06316
# 1                           21.76316
# 2                           21.50000
# 3                           19.55844
# 4                           16.15470
# 5                           15.49249
# 6                           14.33333
# 7                           12.98049
# 8                           12.40150
# 9                           11.99026
# 10                          11.74617
# 11                          11.23385
# 12                          11.20306
# 13                          11.03409
# 14                          10.65400
# 15                          10.02461
# 16                           9.92144
# 17                           9.90950
# 18                           9.58382
# 19                           9.56113
# 20                           9.51566
# 21                           9.50715
# 22                           9.49640
# 23                           9.47010
# 24                           9.36762
# 25                           9.34417
# 26                           9.27595
# 27                           9.26508
# 28                           9.26427
# 29                           8.97222
# 30                           8.94335
# 31                           8.92270
# 32                           8.89685
# 33                           8.82943
# 34                           8.82486
# 35                           8.73490
# 36                           8.72114
# 37                           8.71403
# 38                           8.67114
# 39                           8.62500
# 40                           8.62195
# 41                           8.60079
# 42                           8.56706
# 43                           8.45245
# 44                           8.30314
# 45                           8.29800
# 46                           8.18404
# 47                           8.16471
# 48                           8.01121
# 49                           7.98843
